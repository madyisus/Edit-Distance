# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("log",header=0)
df.columns
# Out:
# Index(['n', 'time_class[ms]', 'time_adap[ms]', 'classic_d', 'adaptive_d'], dtype='object')

# %%
df.plot(kind="area"
        x="n",
        y="time_class[ms]")
# Out:
# <AxesSubplot:xlabel='n'>
